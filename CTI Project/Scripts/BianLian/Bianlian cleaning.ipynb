# %%
import pandas as pd
data = pd.read_excel("Bianlian data desc v1.xlsx")

# %%
import pandas as pd

# Define the keywords for each category
# categories = {
#     "Personal Data (PII - Personally Identifiable Information)": ["personal Data",
#         "Patients’ personal data", "Personal data of employees", "Employees’ personal data", 
#         "Clients’ personal data", "Customer data (IRA/SSN/Passport/Driver’s license)", 
#         "Clients’ PII data", "Patients' PII", "Employees' profiles", "Private personal data", 
#         "Minors’ data", "Clients’ private data", "Passports and ID’s", "Clients’ PII & PHI records", 
#         "Personal information of clients", "Network users personal folders", "Participants' data (participants’)"
#     ],
#     "Sensitive Health Data (PHI - Protected Health Information)": [
#         "Medical and personal data", "Health and medical records", "Patients’ PII and PHI records", 
#         "Medical data", "Patients’ images", "PHI records", "Patients' medical data", 
#         "Clients' health and medical records", "Patients’ PII & PHI data", "Clients' PII & PHI records"
#     ],
#     "Financial Data": [
#         "Company financial data", "Accounting data", "Financial data", "Financial documents", 
#         "Wide companies’ and their projects’ financial data", "Partners’ and clients’ financials", 
#         "Financial conditions of clients", "Client and customer financial data", "Company financial data (budget, settlement, etc.)", 
#         "Clients’ financials and PII", "Clients’ financial conditions and personal data", "Clients' and customers' financials", 
#         "Accounting and business data", "Partners and clients financials", "Vendors’ financials", 
#         "Clients' financials (including international companies like Volkswagen, Ford, etc.)"
#     ],
#     "Business/Operational Data": [
#         "Business data", "Project data", "Operational data", "Clients and customers data", 
#         "Partners’ and clients’ data", "Fileserver data", "Manufacturing data", 
#         "Company data relating to legal cases", "Business correspondence", "Business correspondence and emails", 
#         "Projects and other business data", "Projects and technical data", "Strategic data (potential projects)", 
#         "Local and international business data", "Operational and business files", "Project data (including projects for banks)", 
#         "Data of clients and suppliers", "Clients' data: 625 corporate clients", 
#         "Plans of municipal buildings and construction information", "Emails from network users", "Construction data", 
#         "Auto and cyber insurance policies"
#     ],
#     "Legal/Compliance Data": [
#         "NDA (Non-Disclosure Agreements)", "Contract data", "Court and litigations’ data", 
#         "Legal paperwork", "Incidents & case files", "Court cases", "Confidential agreements", 
#         "Incident and injury reports related to employees", "Settlement data", "Files from CEO and CFO PCs related to legal matters", 
#         "Police and court case files"
#     ],
#     "Technical Data": [
#         "Technical documents", "Electric datasheets", "Engineering and technologies data", "Firmware source codes", 
#         "PCB datasheets & drawings", "Datasheet of microcontrollers", "Technical drawings", 
#         "Engineering data", "Engineering files", "SVN repositories", "R&D data (Research & Development)", 
#         "Geological data", "Design images", "Source codes (including Akumin software source code)", 
#         "SQL backups", "File server data", "Data on competitors' research", "Files of network users’ folders", 
#         "Documents related to hardware technologies", "Files from President's PC"
#     ],
#     "Employee and HR Data": [
#         "HR data", "Employees’ personal and confidential data", "Employees’ profiles", 
#         "Employee data", "Confidential employee information", "Files from employee PCs", "Candidate profiles", 
#         "Incident and injury reports related to employees", "Employees’ confidential data"
#     ],
#     "Client and Customer Data": [
#         "Clients' confidential data", "Clients’ and customers’ financial data", "Clients' and customers’ PII", 
#         "Partners’ and clients’ confidential data", "Clients' health and medical data", "Data of local and international clients", 
#         "Clients’ PII (e.g., SSN, Passport, Driver’s license)", "Insurance data (clients' policies)", 
#         "Clients and customers' private data", "Clients’ financials (including Chinese customers like Geely, Zeekr, Hongqi)", 
#         "Data of network users' folders", "Clients’ financial and private data"
#     ],
#     "Intellectual Property & Confidential Information": [
#         "Trade secrets and recipes", "Intellectual property of third parties", "Recipes and other trade secrets", 
#         "Strategic data: potential projects", "Information on current and closed cases", 
#         "Documents from top management PCs (CEO, CFO, etc.)", "Company strategical plans", 
#         "Data on shareholders and potential investors", "Governmental and military orders", "Examples of company source codes", 
#         "Development technologies and strategies"
#     ],
#     "Email/Communication Data": [
#         "Internal and external email correspondence", "Business email correspondence", "Archived emails", 
#         "Mailboxes & email correspondence (internal/external)", "PST archives", "Emails from top management PCs", 
#         "Email and message archives", "Mailboxes of company employees", "Internal and external email with attachments", 
#         "Company email archives"
#     ],
#     "Incident and Case Data": [
#         "Incident reports", "Accidents and injuries data", "Cases and case files", 
#         "Incidents and accidents", "Incident reports and images", "Court cases", "Police reports", 
#         "Litigation data", "Incidents of injuries", "Case files from legal teams"
#     ],
#     "Database and Backup Data": [
#         "SQL databases", "SQL backups", "Docuware archives", "Archived emails and mailboxes", 
#         "Databases (business and network user data)"
#     ],
#     "Other Specific Data": [
#         "CEO","CFO PCs", "Photos and videos (incidents, cases, and other media)", 
#         "Images and drawings (engineering-related or technical)", "Fileserver data (including internal documents)", 
#         "Nick Curtis, Shane Hartwing, etc.", 
#         "Local and international students’ data and records", "Restricted data (including students’ grades, test results, etc.)", 
#         "Investor and shareholder data"
#     ]
# }

# %%
categories = {
    "Databases": [
        "SQL backups of company partners",
        "SQL databases",
        "Email archives and databases SQL",
        "Data banks of both companies paperwork with it's clients, including confidential files, contracts, etc.",
        "Data from 'Heartland Title Agency' corporate network",
        "SQL bases",
        "Fileserver Data",
        "File server data"
        "QuickBooks"
    ],
    "Applications": [
        "Akumin's software source code",
        "Source codes of over 100 company projects",
        "Firmware Source Codes for Hardware",
        "Technology Data",
        "Docuware archives",
        "SVN repositories"
    ],
    "Emails": [
        "Email and msg archives",
        "Internal email correspondence",
        "External email correspondence",
        "Email archives",
        "Company email archives",
        "Mailboxes",
        "Milboxes",
        "Folders of network users",
        "Corporate email archives including Nick Curtis and Shane Hartwing"
    ],
    "Source Code": [
        "Source codes of over 100 company projects",
        "Akumin's software source code",
        "Firmware Source Codes for Hardware",
        "Source codes & Developments",
        "Examples of company source codes",
        "Technical data",
        "SVN repositories"
    ],
    "Designs": [
        "Blueprints and drawings",
        "PCB Datasheet & Drawings",
        "Design images",
        "Drawings",
        "Project data",
        "Operational Data",
        "Intellectual property of third parties",
        "Engineering files",
        "Construction data",
        "Datasheet of microcontrollers",
        "Technology Data",
        "Projects' data",
        "Images and drawings",
        "Projects (building plans, building communications)",
        "Electric datasheet",
        "Technical data" 
    ],
    "Financial Information": [
        "Company financial data",
        "Accounting, budget, financial data",
        "Finance data",
        "Company's financials",
        "Clients' financial conditions and personal data",
        "Wide companies' and their projects' financial data"
    ],
    "Research Information": [
        "Strategical data: potential projects, geological and mining researches in various countries, data on research of competitors, R&D data",
        "Test results", 
        "Engineering data",
        "Engineering, developments and technologies",
        "Geological data"
    ],
    "Employee Information": [
        "Employee data",
        "HR data",
        "HR Folders",
        "Personnel data",
        "Emploee data",
        "Personal data of employees",
        "Employees profiles",
        "Network users personal folders",
        "Files from President PC",
        "Files from emplee PC"
    ],
    "Customer Information": [
        "Clients personal data",
        "Sensitive customer data",
        "Personal information of clients",
        "Clients' financial conditions and personal data",
        "Client data",
        "Customer audit reports",
        "Personal data of customers",
        "Clients' and Partners' data",
        "Customer Data (SSN/Passport/DL)",
        "Chinese customers (e.g. Geely, Zeekr, Hongqi, etc.)",
        "International customers (e.g. Volkswagen, BMW, Audi, Ford, Porsche, etc.)"
    ],
    "Company Information": [
        "Operational and business data",
        "Business data",
        "Project data",
        "Docuware archives",
        "Files from Top Management PC",
        "Incidents and complaints against products",
        "Intellectual property of third parties",
        "Accidents",
        "Compliance and training materials",
        "Files from CEO and CFO PC",
        "Projects' data",
        "Restricted data",
        "Data of projects and business operating in Africa/CIS and EU contries/Brazil/China and other regions",
        "Casefiles",
        "Incidents' reports and images",
        "Four of AHCLA's relative companies' data",
        "Multiple affiliated companies' data",
        "Data banks of both companies paperwork with it's clients, including confidential files, contracts, etc.",
        "Audit data",
        "Data from 'Heartland Title Agency' corporate network",
        "Company data relating to legal cases",
        "Business data such as board meetings, company strategy development, etc.",
        "Company strategical plans, board meetings and client leads",
        "Network users personal folders",
        "Users personal folders",
        "Files from President PC",
        "Business files",
        "Files from emplee PC",
        "Folders of network users",
        "Incidents & casefiles",
        "Court cases",
        "Incidents"
    ],
    "Backup Systems Information": [
        "Fileserver Data",
        "File server data"
    ],
    "Supply Systems Information": [
        "Data of Vendors and Suppliers",
        "Minerals/graphite/silver/gold and other materials mining fields data",
        "Supply-chain data"
    ],
    "Business Deals Information": [
        "Contract data and NDA's",
        "Business data",
        "Legal Documentation",
        "Settlement data",
        "Investor data",
        "Restricted data",
        "Business files",
        "Data of projects and business operating in Africa/CIS and EU contries/Brazil/China and other regions",
        "Casefiles",
        "Trade & business data",
        "Four of AHCLA's relative companies' data",
        "Multiple affiliated companies' data",
        "Data banks of both companies paperwork with it's clients, including confidential files, contracts, etc.",
        "Audit data",
        "Files from Top Management PC",
        "Business data such as board meetings, company strategy development, etc.",
        "Non-disclosure agreements",
         "Operational Data",
        "Company strategical plans, board meetings and client leads",
        "Contracts and confidential agreements",
        "Business correspondence"
    ],
    "Manufacturing Information": [
        "Manufacturing data",
        "Operational Data",
        "Engineering data",
        "Construction data",
        "Engineering, developments and technologies",
        "Secret recipes and other trade secrets",
        "Recipes and other trade secrets"
    ],
    "Government Information": [
        "Court and Police files",
        "Legal Documentation",
        "International, governmental and military orders",
        "Cases' images and videos",
        "Accidents",
        "Casefiles",
        "Incidents & casefiles",
        "Incidents' reports and images",
        "Plans of municipal buildings and construction information",
        "Information on current and closed cases",
        "Photos and videos",
        "Incidents"
        
    ],
    "Medical Information": [
        "Patients medical and personal data",
        "Medical and Personal Data",
        "A physical and medical history examination",
        "Patients' PII, PHI, and biometric data",
        "Patients' PII and PHI records",
        "Test results",
        "Incidents and injury reports",
        "PHI and PII data"
    ],
    "Personal Information": [
        "Personal information of clients",
        "HR Folders",
        "Users personal folders",
        "Clients' financial conditions and personal data",
        "Personal Data",
        "Private personal data",
        "Patients' PII and PHI records",
        "PHI and PII data",
        "Biometric data",
        "Confidential Personal Data",
        "Personal data of employees",
        "Personal data of customers",
        "A physical and medical history examination",
        "Patients' PII, PHI, and biometric data",
        "Minors' data",
        "Patients medical and personal data",
        "Medical and Personal Data",
        "Passports and ID's"
    ],
    "Others": [
        "Paul Dobrowski personal files",
        "Exhibits",
        "Students' grades",
        "Minerals/graphite/silver/gold and other materials mining fields data",
        "Court cases",
        
    ]
}

# %%
for category in categories:
    data[category] = 0  # Initialize each category column as False

# Function to classify data based on the presence of keywords
def classify_data(text):
    text_lower = str(text).lower()  # Convert the text to lowercase for case-insensitive matching
    for category, keywords in categories.items():
        for keyword in keywords:
            if keyword.lower() in text_lower:  # Check if the keyword is present in the text
                data.at[i, category] = 1  # Set the corresponding category column to True if the keyword is found

# Apply the classification function to each row
for i, row in data.iterrows():
    classify_data(row['data_description'])  

# Save the classified data back to Excel
data.to_excel("classified v3.xlsx", index=False)

print("Classification complete! Check the 'classified_data.xlsx' file for results.")
# Out:
# Classification complete! Check the 'classified_data.xlsx' file for results.
