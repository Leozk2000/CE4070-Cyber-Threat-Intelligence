# %%
import pandas as pd
data = pd.read_excel("Cactus data descriptions.xlsx")

# %%
categories = {
    "Databases": [
        "Databases",
        "SQL",
         "data_description",
        "database exports with client information",
        "database exports with client information, employees' and executive managers personal folders and much more.",
        "database exports",
        "database backups\\exports",
        "database backups\exports",
        "database backups",
        "exports"
    ],
    "Applications": [
        "UserData"
    ],
    "Emails": [
        "corporate correspondence"
    ],
    "Source Code": [
        "Development"
    ],
    "Mechanical Designs": [
        "Engineering\\R&amp;D\\QA documents",
        "R&amp;D",
        "Engineering\\QA data",
        "Engineering data - drawings, r&amp;d, QA",
        "projects and confidential design documents",
        "Drawings",
        "drawings",
        "engineering data\drawings\projects",
        "engineering information",
        "engineering documents",
        "engineering dat"
         "Scans",
        "Mechanical Designs"
    ],
    "Financial Information": [
        "Accounting\\treasury\\taxes",
        "Accounting\\payroll documents",
        "financial documents",
        "financial statements\\payroll",
        "accounting",
         "financial statements\payroll",
        "financial statements\reports",
        "financial documents\statements",
        "financial data",
        "financials",
        "payrolls",
        "financial statements",
        "treasury",
        "taxes",
        "Finance",
        "CFO files",
         "Marketing"
    ],
    "Research Information": [
        "data_description",
         "Projects",
        "Engineering\R&D\QA documents",
        "projects and confidential design documents",
         "Scans",
        "engineering data\drawings\projects",
        "research Information",
        "Development"
    ],
    "Employee Information": [
        "HR - payrolls\\personal documents\\dossiers",
        "employees' and executive managers personal folders",
        "Employees personal and corporate data",
        "executives and employees personal folders",
        "database exports with client information, employees' and executive managers personal folders and much more.",
         "top managers and key employees' personal folders and much more",
        "Employee files",
        "Human Resources",
         "Operations Personnel",
        "employees personal files",
        "employee",
        "personal documents",
        "dossiers",
        "payrolls",
        "executives and employees personal folders",
        "HR confidential data",
         "employees and executive managers personal folders",
         "CFO files",
        "Executives"
    ],
    "Customer Information": [
        "Customer data",
        "Customer Files",
        "legal information",
        "database exports with client information, employees' and executive managers personal folders and much more.",
        "contracts",
        "Services",
         "customer information",
        "Client data",
        "agreements",
         "customer agreements",
        "various customer data",
        "Confidential data from 2 law firms",
        "Clients"
    ],
    "Company Information": [
        "Corporate Data",
        "Sales",
         "Services",
        "legal information",
        "administrative docs",
         "Operations Personnel",
        "Employees personal and corporate data",
        "database exports with client information, employees' and executive managers personal folders and much more.",
        "contracts",
        "corporate correspondence",
        "Projects",
        "correspondence",
        "Management",
        "CorporateData",
        "operational data", 
         "corporate confidential files",
        "corporate confidential data",
        "Company Information",
         "CFO files",
         "Marketing"
    ],
    "Backup Systems Information": [
        "Backup Systems information",
        "database backups"
    ],
    "Supply Systems Information": [
        "Supply systems information"
    ],
    "Business Deals Information": [
        "contracts",
        "tenders",
        "Sales",
        "contracts",
        "agreements",
        "customer agreements",
        "Business deals Information",
        "supplier agreements",
        "NDAs"
    ],
    "Manufacturing Information": [
        "Manufacturing Information"
    ],
    "Government Information": [
        "Government Information"
    ],
    "Others": [
        "Exhibits" ,
        "security officer private photos and files, etc."
      
    ],
    "Personal Information": [
        "Personal Identifying information",
        "Personal Identification information",
        "Employees personal and corporate data",
        "Confidential personal identification data",
        "Identity card",
        "personal documents",
        "Confidential Personal Data",
        "Personal Identification information (passports, DLs, etc)",
        "personal identification documents",
        "Clients' financial conditions and personal data",
        "passports",
        "DLs",
        "Personal data of employees",
        "Personal data of customers",
        "Personal identifiable information"
    ],
    "Medical Information": [
        "Patients medical"
    ]
}

# %%
# categories = {
#     "Databases": [
#         "SQL backups of company partners",
#         "SQL databases",
#         "Email archives and databases SQL",
#         "Data banks of both companies paperwork with it's clients, including confidential files, contracts, etc.",
#         "Data from 'Heartland Title Agency' corporate network",
#         "SQL bases",
#         "Fileserver Data",
#         "File server data"
#         "QuickBooks"
#     ],
#     "Applications": [
#         "Akumin's software source code",
#         "Source codes of over 100 company projects",
#         "Firmware Source Codes for Hardware",
#         "Technology Data",
#         "Docuware archives",
#         "SVN repositories"
#     ],
#     "Emails": [
#         "Email and msg archives",
#         "Internal email correspondence",
#         "External email correspondence",
#         "Email archives",
#         "Company email archives",
#         "Mailboxes",
#         "Milboxes",
#         "Folders of network users",
#         "Corporate email archives including Nick Curtis and Shane Hartwing"
#     ],
#     "Source Code": [
#         "Source codes of over 100 company projects",
#         "Akumin's software source code",
#         "Firmware Source Codes for Hardware",
#         "Source codes & Developments",
#         "Examples of company source codes",
#         "Technical data",
#         "SVN repositories"
#     ],
#     "Designs": [
#         "Blueprints and drawings",
#         "PCB Datasheet & Drawings",
#         "Design images",
#         "Drawings",
#         "Project data",
#         "Operational Data",
#         "Intellectual property of third parties",
#         "Engineering files",
#         "Construction data",
#         "Datasheet of microcontrollers",
#         "Technology Data",
#         "Projects' data",
#         "Images and drawings",
#         "Projects (building plans, building communications)",
#         "Electric datasheet",
#         "Technical data" 
#     ],
#     "Financial Information": [
#         "Company financial data",
#         "Accounting, budget, financial data",
#         "Finance data",
#         "Company's financials",
#         "Clients' financial conditions and personal data",
#         "Wide companies' and their projects' financial data"
#     ],
#     "Research Information": [
#         "Strategical data: potential projects, geological and mining researches in various countries, data on research of competitors, R&D data",
#         "Test results", 
#         "Engineering data",
#         "Engineering, developments and technologies",
#         "Geological data"
#     ],
#     "Employee Information": [
#         "Employee data",
#         "HR data",
#         "HR Folders",
#         "Personnel data",
#         "Emploee data",
#         "Personal data of employees",
#         "Employees profiles",
#         "Network users personal folders",
#         "Files from President PC",
#         "Files from emplee PC"
#     ],
#     "Customer Information": [
#         "Clients personal data",
#         "Sensitive customer data",
#         "Personal information of clients",
#         "Clients' financial conditions and personal data",
#         "Client data",
#         "Customer audit reports",
#         "Personal data of customers",
#         "Clients' and Partners' data",
#         "Customer Data (SSN/Passport/DL)",
#         "Chinese customers (e.g. Geely, Zeekr, Hongqi, etc.)",
#         "International customers (e.g. Volkswagen, BMW, Audi, Ford, Porsche, etc.)"
#     ],
#     "Company Information": [
#         "Operational and business data",
#         "Business data",
#         "Project data",
#         "Docuware archives",
#         "Files from Top Management PC",
#         "Incidents and complaints against products",
#         "Intellectual property of third parties",
#         "Accidents",
#         "Compliance and training materials",
#         "Files from CEO and CFO PC",
#         "Projects' data",
#         "Restricted data",
#         "Data of projects and business operating in Africa/CIS and EU contries/Brazil/China and other regions",
#         "Casefiles",
#         "Incidents' reports and images",
#         "Four of AHCLA's relative companies' data",
#         "Multiple affiliated companies' data",
#         "Data banks of both companies paperwork with it's clients, including confidential files, contracts, etc.",
#         "Audit data",
#         "Data from 'Heartland Title Agency' corporate network",
#         "Company data relating to legal cases",
#         "Business data such as board meetings, company strategy development, etc.",
#         "Company strategical plans, board meetings and client leads",
#         "Network users personal folders",
#         "Users personal folders",
#         "Files from President PC",
#         "Business files",
#         "Files from emplee PC",
#         "Folders of network users",
#         "Incidents & casefiles",
#         "Court cases",
#         "Incidents"
#     ],
#     "Backup Systems Information": [
#         "Fileserver Data",
#         "File server data"
#     ],
#     "Supply Systems Information": [
#         "Data of Vendors and Suppliers",
#         "Minerals/graphite/silver/gold and other materials mining fields data",
#         "Supply-chain data"
#     ],
#     "Business Deals Information": [
#         "Contract data and NDA's",
#         "Business data",
#         "Legal Documentation",
#         "Settlement data",
#         "Investor data",
#         "Restricted data",
#         "Business files",
#         "Data of projects and business operating in Africa/CIS and EU contries/Brazil/China and other regions",
#         "Casefiles",
#         "Trade & business data",
#         "Four of AHCLA's relative companies' data",
#         "Multiple affiliated companies' data",
#         "Data banks of both companies paperwork with it's clients, including confidential files, contracts, etc.",
#         "Audit data",
#         "Files from Top Management PC",
#         "Business data such as board meetings, company strategy development, etc.",
#         "Non-disclosure agreements",
#          "Operational Data",
#         "Company strategical plans, board meetings and client leads",
#         "Contracts and confidential agreements",
#         "Business correspondence"
#     ],
#     "Manufacturing Information": [
#         "Manufacturing data",
#         "Operational Data",
#         "Engineering data",
#         "Construction data",
#         "Engineering, developments and technologies",
#         "Secret recipes and other trade secrets",
#         "Recipes and other trade secrets"
#     ],
#     "Government Information": [
#         "Court and Police files",
#         "Legal Documentation",
#         "International, governmental and military orders",
#         "Cases' images and videos",
#         "Accidents",
#         "Casefiles",
#         "Incidents & casefiles",
#         "Incidents' reports and images",
#         "Plans of municipal buildings and construction information",
#         "Information on current and closed cases",
#         "Photos and videos",
#         "Incidents"
        
#     ],
#     "Medical Information": [
#         "Patients medical and personal data",
#         "Medical and Personal Data",
#         "A physical and medical history examination",
#         "Patients' PII, PHI, and biometric data",
#         "Patients' PII and PHI records",
#         "Test results",
#         "Incidents and injury reports",
#         "PHI and PII data"
#     ],
#     "Personal Information": [
#         "Personal information of clients",
#         "HR Folders",
#         "Users personal folders",
#         "Clients' financial conditions and personal data",
#         "Personal Data",
#         "Private personal data",
#         "Patients' PII and PHI records",
#         "PHI and PII data",
#         "Biometric data",
#         "Confidential Personal Data",
#         "Personal data of employees",
#         "Personal data of customers",
#         "A physical and medical history examination",
#         "Patients' PII, PHI, and biometric data",
#         "Minors' data",
#         "Patients medical and personal data",
#         "Medical and Personal Data",
#         "Passports and ID's"
#     ],
#     "Others": [
#         "Paul Dobrowski personal files",
#         "Exhibits",
#         "Students' grades",
#         "Minerals/graphite/silver/gold and other materials mining fields data",
#         "Court cases",
        
#     ]
# }

# %%
for category in categories:
    data[category] = 0  # Initialize each category column as False

# Function to classify data based on the presence of keywords
def classify_data(text):
    text_lower = str(text).lower()  # Convert the text to lowercase for case-insensitive matching
    for category, keywords in categories.items():
        for keyword in keywords:
            if keyword.lower() in text_lower:  # Check if the keyword is present in the text
                data.at[i, category] = 1  # Set the corresponding category column to True if the keyword is found

# Apply the classification function to each row
for i, row in data.iterrows():
    classify_data(row['data_description'])  

# Save the classified data back to Excel
data.to_excel("classified cactus v9.xlsx", index=False)

print("Classification complete! Check the 'classified_data.xlsx' file for results.")
# Out:
# Classification complete! Check the 'classified_data.xlsx' file for results.
