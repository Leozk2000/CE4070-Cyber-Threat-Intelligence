# %%
import csv
import zipfile
import re
from bs4 import BeautifulSoup

# Define regex patterns for extracting information
company_name_pattern = r'src="/uploads/(.*?)_'
address_pattern = r'Address:\s([^<]+)<'
date_pattern = r'<mark class="marker-yellow"><strong>(\d{2}\.\d{2}\.\d{4})'
revenue_pattern = r'Revenue\s:\s(\$[\d\.]+M)'
industry_pattern = r'<p class="attrs">Industry: <span class="old">(.*?)</span></p>'
data_volume_pattern = r'(\d+(?:\.\d+)?)\s?(TB|Tb|GB|Gb)'
data_description_pattern = r'DATA DESCRIPTIONS:\u003c/strong\u003e\u003c/mark\u003e\s([^<]+)<'  


# Initialize a list to store extracted data
extracted_data = []

# Function to extract data from HTML content
def extract_data(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')

    # Extract data using regex or BeautifulSoup
    company_name = re.search(company_name_pattern, html_content)
    address = re.search(address_pattern, html_content)
    attack_date = re.search(date_pattern, html_content)
    revenue = re.search(revenue_pattern, html_content)
    industry = re.search(industry_pattern, html_content)
    data_volume = re.findall(data_volume_pattern, html_content)
    data_description = re.search(data_description_pattern, html_content)

    # If data_volume is found, concatenate the number and the unit
    if data_volume:
        data_volume = f"{data_volume[0][0]} {data_volume[0][1]}"  # Combine the number and unit
    else:
        data_volume = 'N/A'

    # Store data in a dictionary
    data = {
        'company_name': company_name.group(1) if company_name else 'N/A',
        'address': address.group(1) if address else 'N/A',
        'date_of_attack': attack_date.group(1) if attack_date else 'N/A',
        'revenue': revenue.group(1) if revenue else 'N/A',
        'industry': industry.group(1) if industry else 'N/A',
        'data_volume': data_volume,
        'data_description': data_description.group(1).strip() if data_description else 'N/A',
        
    }

    return data

# Path to the zip file
zip_file_path = 'C:\\Users\\Sruthi\\OneDrive\\Sruthi\\Studies\\Uni\\Uni Courses-Sruthi-Zenbook\\Year 3 Sem 1\\Cyber Threat Intelligence\\Project\\cactus\\cactus scrapped txt.zip'


# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as z:
    # Iterate through each file in the zip
    for file_name in z.namelist():
        # Read the file content
        with z.open(file_name) as file:
            content = file.read().decode('utf-8')
            # Extract data from the content
            extracted_info = extract_data(content)
            extracted_data.append(extract_data(content))
            # Print extracted information
            print(f"Extracted data from file {file_name}:")
            for key, value in extracted_info.items():
                print(f"{key}: {value}")
            print("\n" + "-"*50 + "\n")

csv_columns = ['company_name', 'address', 'date_of_attack', 'revenue', 'industry', 'data_volume', 'data_description']

# Write extracted data to CSV
csv_file = 'extracted_data.csv'
try:
    with open('cactus_extracted_data.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for data in extracted_data:
            writer.writerow(data)
except IOError:
    print("I/O error")
# Out:
# Extracted data from file cactus scrapped txt/:
# company_name: N/A
# address: N/A
# date_of_attack: N/A
# revenue: N/A
# industry: N/A
# data_volume: N/A
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/abzlvlslacizrznq.txt:
# company_name: gocco
# address: &nbsp;CALLE DE LA CALENDULA (MINIPARC III, SOTO DE LA MORALEJA) 93 28109, ALCOBENDAS, Madrid Spain
# date_of_attack: 18.02.2024
# revenue: $937.9M
# industry: N/A
# data_volume: 136 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/afkrwkdpzyshxyqi.txt:
# company_name: geocom
# address: 3071 Dionisio Oribe, Montevideo, Montevideo, 11600, Uruguay
# date_of_attack: 17.12.2023
# revenue: $63.2M
# industry: N/A
# data_volume: 77 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/aqbiyjvfrevsyjol.txt:
# company_name: AXIOM
# address: 1841 Front St Ste A, Lynden, Washington, 98264, United States
# date_of_attack: 18.12.2023
# revenue: $18.9M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/bcpjrrxpfpopivkt.txt:
# company_name: XINDAO
# address: 1d Verrijn Stuartlaan, Rijswijk, South Holland, Netherlands
# date_of_attack: 22.04.2024
# revenue: $50.5M
# industry: N/A
# data_volume: 1 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/bmtovvinbtyrtugx.txt:
# company_name: ODALYS
# address: 2 Rue De La Roquette Passage Du Cheval Blanc Cour De Mai, Paris, France
# date_of_attack: 18.12.2023
# revenue: $151.1M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/btgfaxurucvwuqxy.txt:
# company_name: RENYPICOT
# address: 140 Velazquez, Madrid, Madrid, 28006, Spain
# date_of_attack: 20.03.2024
# revenue: $911.7M
# industry: N/A
# data_volume: 350 GB
# data_description: Accounting\treasury\taxes, HR - payrolls\personal documents\dossiers, Customer data, contracts, Engineering\R&amp;D\QA documents, corporate correspondence, database exports with client information, employees' and executive managers personal folders and much more.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/bturpxkvqtljgxmb.txt:
# company_name: KELSON
# address: 5-593 Norris Ct, Kingston, Ontario, K7P 2R9, Canada
# date_of_attack: 28.03.2024
# revenue: $61.8M
# industry: N/A
# data_volume: 1.5 TB
# data_description: Accounting\payroll documents, Personal Identifying information, Engineering\QA data, projects and confidential design documents, contracts, tenders, various customer data, employees and executive managers personal folders, database exports, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/bvpkebdnmttbpnat.txt:
# company_name: FLODRAULIC
# address: 3539 N 700 W, Greenfield, Indiana, 46140, United States
# date_of_attack: 15.09.2024
# revenue: $58.4M
# industry: N/A
# data_volume: 32 GB
# data_description: Employees personal and corporate data, customer information, contracts, projects, drawings, financial documents, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/bvvsfnittneqhowb.txt:
# company_name: HYDMECH
# address: 1079 Parkinson Rd, Woodstock, Ontario, N4S 0A9, Canada
# date_of_attack: 10.07.2024
# revenue: $47.2M
# industry: N/A
# data_volume: 980 GB
# data_description: Engineering data - drawings, r&amp;d, QA, Personal Identification information (passports, DLs, etc.), customer agreements, HR confidential data, executives and employees personal folders, financial statements\payroll, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/bxmxaryiewjmovpz.txt:
# company_name: 123
# address: 9340 De Meaux St, Montreal, Quebec, H1R 3H2, Canada
# date_of_attack: 02.08.2023
# revenue: $398.5M
# industry: N/A
# data_volume: 82 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/cbhiieispxrgtphq.txt:
# company_name: OFFICE
# address: 2572 S Union Ave, Bakersfield, California, 93307, United States
# date_of_attack: 07.07.2024
# revenue: $70.8M
# industry: N/A
# data_volume: 180 GB
# data_description: Personal identifiable information, financial documents, corporate confidential files, employees and executives personal files, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/cbvrpzxqpgdasdnh.txt:
# company_name: PAULSTUART
# address: Ny-new Madison Avenue &amp; East 45th St, New York City, New York, 10017, United States
# date_of_attack: 18.12.2023
# revenue: $24.1M
# industry: N/A
# data_volume: 230 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ccuezelyvrahgfly.txt:
# company_name: VERCO
# address: 67 Clerkenwell Rd, London, Greater London, EC1R 5BL, United Kingdom
# date_of_attack: N/A
# revenue: $17.5M
# industry: N/A
# data_volume: 592 GB
# data_description: Personal identifiable information, corporate confidential data, contracts, engineering data\drawings\projects, employees and executives personal files, financial documents\statements, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/cermczldqkpbrfmq.txt:
# company_name: 12233
# address: 3040 Post Oak Blvd Ste 1030, Houston, Texas, 77056, United States
# date_of_attack: 03.09.2023
# revenue: $24.7M
# industry: N/A
# data_volume: 100 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ciixceiueurursjj.txt:
# company_name: BOATS
# address: 187 Peanut Dr, Edenton, North Carolina, 27932, United States
# date_of_attack: 13.05.2024
# revenue: $28.1M
# industry: N/A
# data_volume: 630 GB
# data_description: Thousands of engineering documents and drawings, administrative docs, corporate correspondence, employees and executive managers personal data, Personal Identifying information, database backups\exports, etc
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/cjryxcvdlucwqskp.txt:
# company_name: 1235555555
# address: 188 High St, Ripley, Surrey, GU23 6BD, United Kingdom
# date_of_attack: 30.07.2023
# revenue: $43.8M
# industry: N/A
# data_volume: 250 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/cmxbkiinhlwzsqbv.txt:
# company_name: BBC
# address: 1221 W Coast Hwy, Newport Beach, California, 92663, United States
# date_of_attack: 15.09.2024
# revenue: $101M
# industry: N/A
# data_volume: 790 GB
# data_description: Personal Identifiable Information, employees\executives personal data, customer information, financial data, contracts, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/comfkxumvnmlizll.txt:
# company_name: EBIR
# address: 9 Calle El Perell√≥, Torrent, Valencia, 46900, Spain
# date_of_attack: 18.04.2024
# revenue: $5M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/csjtsrcbkmddwosi.txt:
# company_name: 123
# address: 4275 Burton Dr, Santa Clara, California, 95054, United States
# date_of_attack: 20.12.2023
# revenue: $66.1M
# industry: N/A
# data_volume: 600 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/cstzthlpkkrxwpkz.txt:
# company_name: 5555555
# address: 168 Skene St, Aberdeen, Aberdeen City, AB10 1PE, United Kingdom&nbsp;
# date_of_attack: N/A
# revenue: $34.8M
# industry: N/A
# data_volume: 620 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/cwiwmyqectsshmcd.txt:
# company_name: LOGO
# address: 18 Via Bergamo Pregnana Milanese, Cornaredo, Lombardy, 20010, Italy
# date_of_attack: N/A
# revenue: $203.7M
# industry: N/A
# data_volume: 12.5 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/cwlkskbejvqhvhrc.txt:
# company_name: CTS
# address: 30 Church St, Kidderminster, West Midlands, DY10 2AX, United Kingdom
# date_of_attack: N/A
# revenue: $23.2M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/dioqhawhtgfhetwr.txt:
# company_name: WKW
# address: 235 Hahnerberger Straãÿe, Wuppertal, Nordrhein-Westfalen, 42349, Germany
# date_of_attack: 12.01.2024
# revenue: $707M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/dqlkklxmywnxxftj.txt:
# company_name: 777777777
# address: 2 Eastern Road, South Melbourne, Vic 3205, AUSTRALIA
# date_of_attack: 24.12.2023
# revenue: $66.1M
# industry: N/A
# data_volume: 440 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/eqihekvxaxnlylnw.txt:
# company_name: CIE
# address: 69 Alameda Mazarredo 8º, Bilbao, Basque Country, 48009, Spain
# date_of_attack: 20.12.2023
# revenue: $66.1M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/equkrpjooahejhxd.txt:
# company_name: LOGO
# address: Av Parque de Chapultepec 56, El Parque, 53398 Naucalpan de Juárez, Méx., Mexico
# date_of_attack: 19.05.2024
# revenue: $23.6M
# industry: N/A
# data_volume: 387 GB
# data_description: Personal Identification information, corporate documents, legal information, financial data\payroll\reports, employee personal data, correspondence, customer information, contracts, database backups.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ewrnqegywqajwukk.txt:
# company_name: 12344
# address: 350 W Rosecrans Ave, Gardena, California, 90248, United States
# date_of_attack: 30.08.2023
# revenue: $75.7M
# industry: N/A
# data_volume: 107 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ffhrodqpjkgvruyr.txt:
# company_name: 1234
# address: 300-1055 W Hastings St, Vancouver, British Columbia, V6E 2E9, Canada
# date_of_attack: 18.04.2024
# revenue: $243.7M
# industry: N/A
# data_volume: 41 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/flzeqazscpblixvr.txt:
# company_name: 12333333
# address: 31 a Via Novara, Ivrea, Piedmont, 10015, Italy
# date_of_attack: 19.12.2023
# revenue: $25.5M
# industry: N/A
# data_volume: 80 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/fsvhcawhvnkijdsg.txt:
# company_name: LAJOLLA
# address: 14350 Myford Rd Ste 100, Irvine, California, 92606, United States
# date_of_attack: 21.12.2023
# revenue: $35.2M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/fxjasckdwhiuhqbv.txt:
# company_name: LOGO
# address: Albion Retail Park Albion Way, Blyth, Northumberland, NE24 5BW, United Kingdom
# date_of_attack: N/A
# revenue: $50.7M
# industry: N/A
# data_volume: 6 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/gaupkclajrwuifcr.txt:
# company_name: 222222
# address: 4 Zac St Jacques Ii, Maxeville, 54320, France
# date_of_attack: 24.12.2023
# revenue: $55.8M
# industry: N/A
# data_volume: 790 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/gblmmfedbhjxkvav.txt:
# company_name: 123
# address: 63 Ave Dos Descobrimentos, Vila Nova de Famalicao, Braga, 4760-011, Portugal
# date_of_attack: N/A
# revenue: $13.4M
# industry: N/A
# data_volume: 109 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ggjbnpbwjlikoiym.txt:
# company_name: EXCO
# address: 9-11 Adam-opel-straße, Frankenthal, Rheinland-Pfalz, 67227, Germany
# date_of_attack: 28.08.2024
# revenue: $76.4M
# industry: N/A
# data_volume: 251 GB
# data_description: Personal Identifiable Information, employees and executives personal and corporate data, customer data, financial documents, contracts, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/glkuaouvhmhnmghu.txt:
# company_name: REGENCYFURNITUR
# address: 10318 Portsmouth Rd, Manassas, Virginia, 20109, United States
# date_of_attack: 15.04.2024
# revenue: $369M
# industry: N/A
# data_volume: 300 GB
# data_description: Personal Identifying information, financial statements, corporate correspondence, contracts, employee and customer information, executive managers personal data, database backups, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/gsibjizaemlqzgxf.txt:
# company_name: LOGO
# address: 1 Lone Star Pass Bldg 28, San Antonio, Texas, 78264, United States
# date_of_attack: N/A
# revenue: $73M
# industry: N/A
# data_volume: 31 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/gtokfwurwlquywpu.txt:
# company_name: Logo
# address: Galvanistraat 119, 6716 AE Ede, NL
# date_of_attack: 13.05.2024
# revenue: $80.1M
# industry: N/A
# data_volume: 1 TB
# data_description: Personal identifying information, financial documents, customer data, database exports, various confidential documents, corporate correspondence, employees personal documents, private software sources, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/gwxkmctkpmvdbhpu.txt:
# company_name: MCO
# address: 5559 W Gowen Rd 100, Boise, Idaho, 83709, United States
# date_of_attack: 15.04.2024
# revenue: $199M
# industry: N/A
# data_volume: 1.2 TB
# data_description: Сonfidential personal identification data, private information, financial data, construction projects, agreements, drawings, corporate correspondence, accounting, operational data, top managers and key employees' personal folders and much more.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/hovcsqfttzdzadby.txt:
# company_name: Confartigianato
# address: 49 Via Ilaria Alpi, Cesena, Emilia-Romagna, 47023, Italy
# date_of_attack: N/A
# revenue: $11.4M
# industry: N/A
# data_volume: 25 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/htsjjokxhhqctidx.txt:
# company_name: 7777777
# address: 7075 Fm 38 N, Brookston, Texas, 75421, United States
# date_of_attack: 24.12.2023
# revenue: $40.4M
# industry: N/A
# data_volume: 240 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/hukuhydteyaltzpt.txt:
# company_name: multimasters
# address: 620 Beversesteenweg, Roeselare, Flanders, 8800, Belgium
# date_of_attack: 18.12.2023
# revenue: $604.9M
# industry: N/A
# data_volume: 175 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/igfrgpopgkbtvkdw.txt:
# company_name: NNDOMAIN
# address: 2964 Clydon Ave SW, Grand Rapids, Michigan, 49519, United States
# date_of_attack: 19.12.2023
# revenue: $678.9M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/inheqfoqkaloonck.txt:
# company_name: AIRDRIE
# address: Bell Business Park Rochsolloch Rd, Airdrie, North Lanarkshire, ML6 9BG, United Kingdom
# date_of_attack: 12.01.2024
# revenue: $103.6M
# industry: N/A
# data_volume: 9 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ipjtfuihynorgmsb.txt:
# company_name: 1233333
# address: 50 W Wilmot St Unit 6, Richmond Hill, Ontario, L4B 1M5, Canada
# date_of_attack: 21.12.2023
# revenue: $186.9M
# industry: N/A
# data_volume: 638 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ivmntyjhmjughpfd.txt:
# company_name: ICIREALESTATE
# address: 4301 Westside Dr Ste 100, Dallas, Texas, 75209, United States
# date_of_attack: 18.01.2024
# revenue: $31.1M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/iwzvzvkqvrybssmu.txt:
# company_name: AM
# address: 45 Beacon St, Boston, Massachusetts, 02108, United States
# date_of_attack: N/A
# revenue: $16M
# industry: N/A
# data_volume: 21 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/jcidlzhatgzjqyuq.txt:
# company_name: Petersen
# address: 830 W Trailcreek Dr, Peoria, Illinois, 61614, United States
# date_of_attack: 20.12.2023
# revenue: $172.5M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/jfzebiyvhwdzszth.txt:
# company_name: download
# address: \u003cspan style=\"background-color:rgb(255,255,255);color:rgb(1,13,57);font-family:Montserrat, sans-serif;\"\u003e24 Via Emilia, San Donato Milanese, Lombardy, 20097, Italy\u003c/span\u003e\u003c/p\u003e\u003cp\u003ePhone Number: \u003cspan style=\"background-color:rgb(255,255,255);color:rgb(1,13,57);font-family:Montserrat, sans-serif;\"\u003e+39 117419881\u003c/span\u003e\u003c/p\u003e\u003cp\u003e\u003cmark class=\"marker-yellow\"\u003e\u003cstrong\u003eDownload link #1:\u003c/strong\u003e\u003c/mark\u003e\u003c/p\u003e\u003cp\u003e\u003ca href=\"https://vhfd5qagh6j7qbisjqvly7eejqbv6z5bv77v6yuhctn77wmd3hjkyvad.onion/CWS/NNTY9405OsSD2/CWS_PROOF_OF_HACK.zip\"\u003ehttps://vhfd5qagh6j7qbisjqvly7eejqbv6z5bv77v6yuhctn77wmd3hjkyvad.onion/CWS/NNTY9405OsSD2/CWS_PROOF_OF_HACK.zip\u003c/a\u003e\u003c/p\u003e\u003cp\u003e\u003cmark class=\"marker-yellow\"\u003e\u003cstrong\u003eDownload link #2:\u003c/strong\u003e\u003c/mark\u003e\u003c/p\u003e\u003cp\u003e\u003ca href=\"https://vhfd5qagh6j7qbisjqvly7eejqbv6z5bv77v6yuhctn77wmd3hjkyvad.onion/CWS/dSADbjh2322/ClientData.zip\"\u003ehttps://vhfd5qagh6j7qbisjqvly7eejqbv6z5bv77v6yuhctn77wmd3hjkyvad.onion/CWS/dSADbjh2322/ClientData.zip\u003c/a\u003e\u003c/p\u003e\u003cp\u003e\u003cimg src=\"/uploads/Certificato_Morte_Guzzi_Vincenzo_c4009445f9.png\" alt=\"CertificatoMorteGuzziVincenzo.png\"\u003e\u003cimg src=\"/uploads/CI_CF_Marilisa_Stagliano_867225c549.png\" alt=\"CI_CF_Marilisa_Stagliano.png\"\u003e\u003cimg src=\"/uploads/Fatturato_CEO_c0f2eb973d.png\" alt=\"Fatturato CEO.png\"\u003e\u003cimg src=\"/uploads/Mensa_Versino_Christian_36dd686424.png\" alt=\"Mensa_VersinoChristian.png\"\u003e\u003cimg src=\"/uploads/20220207_Stampa_scadenziario_per_cliente_f63a90014d.png\" alt=\"20220207 Stampa scadenziario per cliente.png\"\u003e\u003c/p\u003e","createdAt":"2023-07-04T12:42:19.774Z","updatedAt":"2024-09-20T16:39:06.688Z","publishedAt":"2023-07-04T12:53:24.920Z","image":{"data":{"id":70,"attributes":{"name":"download (2).png","alternativeText":null,"caption":null,"width":1000,"height":400,"formats":{"small":{"ext":".png","url":"/uploads/small_download_2_2c6e5ae1a6.png","hash":"small_download_2_2c6e5ae1a6","mime":"image/png","name":"small_download (2).png","path":null,"size":18.4,"width":500,"height":200},"medium":{"ext":".png","url":"/uploads/medium_download_2_2c6e5ae1a6.png","hash":"medium_download_2_2c6e5ae1a6","mime":"image/png","name":"medium_download (2).png","path":null,"size":36.69,"width":750,"height":300},"thumbnail":{"ext":".png","url":"/uploads/thumbnail_download_2_2c6e5ae1a6.png","hash":"thumbnail_download_2_2c6e5ae1a6","mime":"image/png","name":"thumbnail_download (2).png","path":null,"size":8.16,"width":245,"height":98}},"hash":"download_2_2c6e5ae1a6","ext":".png","mime":"image/png","size":12.9,"url":"/uploads/download_2_2c6e5ae1a6.png","previewUrl":null,"provider":"local","provider_metadata":null,"createdAt":"2023-07-04T13:05:31.595Z","updatedAt":"2023-07-04T13:05:31.595Z"}}}}},"posts":{"data":[{"id":171,"attributes":{"title":"thomas-lloyd.com\\$66.1M\\USA\\2.4TB\\\u003c1% DISCLOSED","slug":"TLG","excerpt":null,"url":null,"views":"3047","content":"\u003cp\u003eFinance\u003cbr\u003e\u003cbr\u003e“ThomasLloyd is a global investment and advisory firm dedicated to leading the necessary process for social and environmental change, focusing exclusively on the financing, construction and operation of sustainable projects in the infrastructure, agriculture and property sectors.”\u003cbr\u003e\u003cbr\u003eWebsite: \u003ca href=\"https://www.thomas-lloyd.com/\"\u003ehttps://www.thomas-lloyd.com/\u003c/a\u003e\u003cbr\u003e\u003cbr\u003eRevenue : $66.1M\u003cbr\u003e\u003cbr\u003eAddress: 427 Bedford Rd, Pleasantville, New York, 10570, United States\u003cbr\u003e\u003cbr\u003ePhone Number: (914) 495-3630\u003cbr\u003e\u003cbr\u003e\u003cmark class=\"marker-yellow\"\u003e\u003cstrong\u003eDownload link #1:\u003c/strong\u003e\u003c/mark\u003e \u0026nbsp;\u003ca href=\"https://6wuiv ...
# date_of_attack: N/A
# revenue: $66.1M
# industry: N/A
# data_volume: 6.5 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/jkgbtgyagofjdegj.txt:
# company_name: SKY
# address: 36 Tømrervej, Varde, Region Syddanmark, 6800, Denmark
# date_of_attack: 09.07.2024
# revenue: $26.4M
# industry: N/A
# data_volume: 50 GB
# data_description: Personal identifiable information, corporate agreements, projects, financial documents, employees and executives personal files, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/jnoniwgodypkvskb.txt:
# company_name: 55555
# address: 12859 Wetmore Rd, San Antonio, Texas, 78247, United States
# date_of_attack: 04.09.2023
# revenue: $19.1M
# industry: N/A
# data_volume: 170 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/jqkzzmlvntrhidtn.txt:
# company_name: SMI
# address: 1604 Morrison Ave, Rothschild, Wisconsin, 54474, United States
# date_of_attack: 23.05.2024
# revenue: $28.9M
# industry: N/A
# data_volume: 280 GB
# data_description: Financial documents, supplier agreements, contracts, NDAs, Personal identifying information, Engineering data, employee personal files, database exports, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/jrbowotqpnrxllve.txt:
# company_name: PBS
# address: 4041 128 Ave SE, Calgary, Alberta, T2Z 5G6, Canada
# date_of_attack: 12.01.2024
# revenue: $71.5M
# industry: N/A
# data_volume: 202 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/kbctywkambioakii.txt:
# company_name: CONCORDE
# address: 2507 16 St SE, Calgary, Alberta, T2G 3R4, Canada
# date_of_attack: 18.04.2024
# revenue: $150M
# industry: N/A
# data_volume: 2 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/kbgctwmcbwlmbquh.txt:
# company_name: JGM
# address: The Pl Fl 2, Sandton, 2146, South Africa
# date_of_attack: 07.07.2024
# revenue: $11.3M
# industry: N/A
# data_volume: 105 GB
# data_description: Employees and executives personal files, personal identifiable information, financial documents, corporate confidential files, correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/kfrraofkzaixdzxa.txt:
# company_name: DESKCENTER
# address: Arthur-Hoffmann-Straße 175, 04277, Leipzig, Germany
# date_of_attack: 07.07.2024
# revenue: $25.9M
# industry: N/A
# data_volume: 224 GB
# data_description: Employees personal and corporate data, personal identifying documents, financial documents, customer information, database backups\exports, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/khfykolovmcpuqui.txt:
# company_name: LOGO
# address: South Tower 10 Glenlake Pkwy Ste 600, Atlanta, Georgia, 30328, United States
# date_of_attack: N/A
# revenue: $66.1M
# industry: N/A
# data_volume: 25 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/kpkowcnuexmkmflt.txt:
# company_name: DEMOSGROUP
# address: 1 Parvis De La Defense, Nanterre, Ile-de-France, 92000, France
# date_of_attack: 07.08.2024
# revenue: $37.5M
# industry: N/A
# data_volume: 870 GB
# data_description: Personal identifiable information, corporate confidential data, NDA, contracts, employees and executives personal files, financial documents\statements, customer information, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/kqchatmudvxjohgj.txt:
# company_name: QOSINA
# address: 2002q Orville Dr N, Ronkonkoma, New York, 11779, United States
# date_of_attack: 26.03.2024
# revenue: $37.9M
# industry: N/A
# data_volume: 375 GB
# data_description: Financial documents, employee and executive managers personal data, engineering documents and drawings, QA data, customer information, contracts, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ktjiouhjudnsxior.txt:
# company_name: 123455455555555
# address: 200 Adelaide St S, London, Ontario, N5Z 3L1, Canada
# date_of_attack: 22.12.2023
# revenue: $33.4M
# industry: N/A
# data_volume: 189 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ktnrozevefertfbw.txt:
# company_name: BESTTRANS
# address: 263 Distribution St, Newark, New Jersey, 07114, United States
# date_of_attack: 15.04.2024
# revenue: $24.8M
# industry: N/A
# data_volume: 24 GB
# data_description: Employees and executives personal folders, financial statements, payroll data, customer agreements, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/lctxjxwvehghtprd.txt:
# company_name: JMCINTERNET
# address: 491 Rte 253, Saint Malo, Quebec, J0B 2Y0, Canada
# date_of_attack: 16.09.2024
# revenue: $25.5M
# industry: N/A
# data_volume: 130 GB
# data_description: Personal Identifiable Information, employees\executives personal data, engineering documents\projects\drawings, customer information, financial documents, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/lendzayoxdlgfzpv.txt:
# company_name: SIMSONMAXWELL
# address: 467 Exploration Ave SE, Calgary, Alberta, T3S 0B4, Canada
# date_of_attack: 10.09.2024
# revenue: $29.4M
# industry: N/A
# data_volume: 357 GB
# data_description: Personal Identifiable Information, Employees personal and corporate data, customer information, contracts, projects, drawings, financial documents, corporate and personal correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/lhgmjtjtywqqlmgb.txt:
# company_name: CTSYSTEM
# address: 18f-6 no.79 Sec.1 Xintai 5th Rd, Xizhi Dist., New Taipei City, 221, Taiwan
# date_of_attack: 21.06.2024
# revenue: $11.8M
# industry: N/A
# data_volume: 93 GB
# data_description: Corporate confidential data, engineering documents, financial data, customer information, personal identification documents, database backups, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/lqowpmjcuverflzi.txt:
# company_name: SOFIDSAP
# address: 23 Via Lazzareschi, Porcari, Tuscany, 55016, Italy
# date_of_attack: 09.07.2024
# revenue: $66.1M
# industry: N/A
# data_volume: 74 GB
# data_description: Personal identifiable information, financial documents, employees and executives personal files, customer information, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/lswxdbcyncqrckls.txt:
# company_name: CCS
# address: Heather Park House N Circular Rd, London, Greater London, NW10 7NN, United Kingdom
# date_of_attack: 21.03.2024
# revenue: $239.3M
# industry: N/A
# data_volume: 1 TB
# data_description: Accounting\treasury\taxes 40GB+, HR - payrolls\personal documents\dossiers 110GB+, Customer data - projects\contracts\drawings 130GB+, Engineering\R&amp;D\QA, Legal documents 3GB+, corporate correspondence 120GB+, employees' personal folders, database exports\backups... Thousands of financial documents, employees background reports including Personal Identifying information, contracts and tenders, executive directors personal and corporate data, engineering database exports and much more.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/lszomlvhvnrroifj.txt:
# company_name: MIHLFELD
# address: 2841 E Division St, Springfield, Missouri, 65803, United States
# date_of_attack: 28.08.2024
# revenue: $88.2M
# industry: N/A
# data_volume: 316 GB
# data_description: Employees personal and corporate data, Personal Identifiable Information, financial documents, customer information, contracts, corporate and personal correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/maawheaahvpbmkmc.txt:
# company_name: TRANSLAB
# address: 1050 Norman St, Lasalle, Quebec, H8S 1A5, Canada
# date_of_attack: 10.07.2024
# revenue: $27.8M
# industry: N/A
# data_volume: 110 GB
# data_description: Employees personal and corporate data, Personal Identifiable Information, financial documents, customer information, corporate and personal correspondence, database exports, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/mjggbwnaztkyngeb.txt:
# company_name: TIBA
# address: Jardines Universidad, Zapopan, Jalisco, 45110, Mexico
# date_of_attack: 28.08.2024
# revenue: $124.3M
# industry: N/A
# data_volume: 29 GB
# data_description: Personal Identifiable Information, employees and executives personal and corporate data, financial documents, contracts, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/mryhdmhdsrdvggqm.txt:
# company_name: DAYSTAR
# address: 121 Shattuck Way Ste 10, Portsmouth, New Hampshire, 03801, United States
# date_of_attack: 07.07.2024
# revenue: $120.3M
# industry: N/A
# data_volume: 125 GB
# data_description: Personal identifiable information, corporate confidential documents, financial data, personnel information, employees personal files, legal documents, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/mryyijkqeeqgtqum.txt:
# company_name: AMMEGA
# address: 8 Comeniusstraat, Alkmaar, North Holland, 1817 MS, Netherlands
# date_of_attack: 21.04.2024
# revenue: $66.1M
# industry: N/A
# data_volume: 3 TB
# data_description: Accounting\treasury\taxes 250GB+, HR - payrolls\personal documents\dossiers 150GB+, Customer data - projects\contracts\drawings 100GB+, Engineering\R&amp;D\QA 250GB+, Legal documents, corporate correspondence 100GB+, employees' personal folders... Lots of corporate confidential data, employees Personal Identifying information, executive managers personal data, legal documents including lawsuits, contracts, etc.&nbsp;
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/mzftlcsnszhvulwr.txt:
# company_name: 11111
# address: 2725 Texas Central Pkwy, Waco, Texas, 76712, United States
# date_of_attack: 21.12.2023
# revenue: $30.3M
# industry: N/A
# data_volume: 48 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/nbvoiimbaqupnygj.txt:
# company_name: 5555
# address: 12 Rue Cabanis, Paris, Île-de-france, 75014, France
# date_of_attack: 24.12.2023
# revenue: $40.8M
# industry: N/A
# data_volume: 435 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/nlfnivgxanbodskn.txt:
# company_name: 1232123
# address: 11-13 Stamford Rd, Oakleigh, Victoria, 3166, Australia
# date_of_attack: 20.12.2023
# revenue: $19.8M
# industry: N/A
# data_volume: 25 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/nngzjytuwuqqcbla.txt:
# company_name: NEWAGESYS
# address: 4390 Us-1 Ste 110, Princeton, New Jersey, 08540, United States
# date_of_attack: 28.03.2024
# revenue: $24.1M
# industry: N/A
# data_volume: 319 GB
# data_description: Accounting\payroll\tax documents, HR data, Personal Identifying information, background reports, corporate correspondence\mailbox backups, employees personal folders, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/nqrrbfjgrdpldfgl.txt:
# company_name: DTS
# address: 100 Augusta Arbor Way, Greenville, South Carolina, 29605, United States
# date_of_attack: 28.01.2024
# revenue: $31.1M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ntkhvrfjfytrqdam.txt:
# company_name: LEONARDDOMAIN
# address: 4601 Nancy St, Detroit, Michigan, 48212,, United States
# date_of_attack: 05.08.2024
# revenue: $22M
# industry: N/A
# data_volume: 575 GB
# data_description: Employees personal and corporate data, Personal Identifiable Information, accounting, financial documents, customer data, contracts, corporate correspondence, database exports etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ntnsjxaeoccyxtyg.txt:
# company_name: 1111
# address: Arrow Works Birmingham Rd, Studley, West Midlands, B80 7AS, United Kingdom
# date_of_attack: 18.12.2023
# revenue: $29.5M
# industry: N/A
# data_volume: 248 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/nuocxdwzfyjxkhdv.txt:
# company_name: CBS
# address: 10 Leigh Rd, Street, Somerset, BA16 0HA, United Kingdom
# date_of_attack: 05.08.2024
# revenue: $14M
# industry: N/A
# data_volume: 362 GB
# data_description: Personal identifiable information, customer confidential information, litigation documents, corporate confidential data, NDA, contracts, employees and executives personal files, financial documents\statements, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/oelljemyuchknqfx.txt:
# company_name: MCPHILLIPS
# address: Horton House Hortonwood 50, Telford, Shropshire, TF1 7FG, United Kingdom
# date_of_attack: 10.09.2024
# revenue: $40.8M
# industry: N/A
# data_volume: 1.2 TB
# data_description: Personal Identifiable Information, customer information, engineering data\drawings\projects, employees\executives personal data, financial documents, contracts, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/onptjytfaexapexx.txt:
# company_name: DAI
# address: 8 John St, Hoosick Falls, New York, 12090, United States
# date_of_attack: 05.08.2024
# revenue: $18.1M
# industry: N/A
# data_volume: 80 GB
# data_description: Personal identifiable information, corporate confidential data, customers data, contracts, employees and executives personal files, financial documents\statements, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ovabjpuqxloxhgjh.txt:
# company_name: 111111111
# address: 918 Ahua St, Honolulu, Hawaii, 96819, United States
# date_of_attack: 09.09.2023
# revenue: $24.9M
# industry: N/A
# data_volume: 28 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/pbhtithigplkflmh.txt:
# company_name: LOGO
# address: 12/ab Strada Rivoltana Sp 14, Vignate, Lombardy, 20060, Italy
# date_of_attack: N/A
# revenue: $57M
# industry: N/A
# data_volume: 8 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/pbppdvqctisnhepe.txt:
# company_name: download
# address: Iconix One London Sawston Rd, Cambridge, Cambridgeshire, CB22 3EG, United Kingdom
# date_of_attack: N/A
# revenue: $152.3M
# industry: N/A
# data_volume: 92 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/phijgwscuyckrsap.txt:
# company_name: 111
# address: 4770 Bryant Irvin Ct Ste 200, Fort Worth, Texas, 76107, United States
# date_of_attack: 19.12.2023
# revenue: $9M
# industry: N/A
# data_volume: 102 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/pntktlkvuehdjywz.txt:
# company_name: RANGERAMERICAN
# address: 605 Marginal Lodi 65, San Juan, Puerto Rico, 00929, United States
# date_of_attack: 10.09.2024
# revenue: $52.9M
# industry: N/A
# data_volume: 218 GB
# data_description: Personal Identifiable Information, customer info, contracts, employees\executives personal and corporate data, accounting\payroll, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/poeszbvuhenizvpg.txt:
# company_name: KONSUM
# address: 4 Englundavägen, Solna, 171 41, Sweden
# date_of_attack: 12.01.2024
# revenue: $66.1M
# industry: N/A
# data_volume: 257 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/psppewruzucdzouc.txt:
# company_name: HICONE
# address: 1140 W Bryn Mawr Ave, Itasca, Illinois, 60143, United States
# date_of_attack: 29.01.2024
# revenue: $27M
# industry: N/A
# data_volume: 650 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/pynhoaqopmakidvr.txt:
# company_name: RIOMARINEINC
# address: 5301 Polk St Bldg 12, Houston, Texas, 77023, United States
# date_of_attack: 16.09.2024
# revenue: $56M
# industry: N/A
# data_volume: 490 GB
# data_description: Personal Identifiable Information, employees\executives personal data, engineering data\drawings\projects, customer information, financial documents, contracts, corporate correspondence, database backups etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/qdmdpmdcddwkueon.txt:
# company_name: STA
# address: 10 Commerce Dr, Gaffney, South Carolina, 29340, United States
# date_of_attack: 30.06.2024
# revenue: $71.3M
# industry: N/A
# data_volume: 278 GB
# data_description: Personal identification documents, corporate data, drawings, financial documents, supplier\customer information, employee personal data, corporate and personal correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/qjmsnbelahxmnyho.txt:
# company_name: 111111
# address: 5600 Norris Rd, Bakersfield, California, 93308, United States
# date_of_attack: 22.12.2023
# revenue: $11.8M
# industry: N/A
# data_volume: 350 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/qmuploxpapkazrtu.txt:
# company_name: 123
# address: 102-1051 Talbot Blvd, Chicoutimi, Quebec, G7H 4B5, Canada
# date_of_attack: 01.10.2023
# revenue: $17.7M
# industry: N/A
# data_volume: 270 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/qmvvvxlyvjkuzsyz.txt:
# company_name: WWBEV
# address: PO Box 1336, Rock Springs, Wyoming, 82902, United States
# date_of_attack: 05.08.2024
# revenue: $59.2M
# industry: N/A
# data_volume: 102 GB
# data_description: Database exports, Employee personal files, personal Identifiable Information, financial data, customer data, contracts, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/qpdmexocsijiwhbo.txt:
# company_name: DAHLVALVE
# address: 2600 S Sheridan Way, Mississauga, Ontario, L5J 2M4, Canada
# date_of_attack: 05.08.2024
# revenue: $23.9M
# industry: N/A
# data_volume: 80 GB
# data_description: Personal identifiable information, corporate confidential data, agreements, contracts, engineering data\drawings\projects, employees and executives personal files, financial documents\statements, corporate correspondence, database backups etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/qrhkersjicjcfyhg.txt:
# company_name: 222222fff
# address: 565 Taxter Rd Ste 620, Elmsford, New York, 10523, United States
# date_of_attack: 18.12.2023
# revenue: $288.5M
# industry: N/A
# data_volume: 134 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/rcjnfpqzucbgugxw.txt:
# company_name: SANYOSHOKAI
# address: 6-14 Yotsuyahonshio-cho, Honshiocho, Tokyo, 160-0003, Japan
# date_of_attack: 21.06.2024
# revenue: $412.6M
# industry: N/A
# data_volume: 248 GB
# data_description: Personal identifying information, financial documents, customer data, engineering information, employee\executives personal files, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/rknxumejbkondchr.txt:
# company_name: logo
# address: 82 Av. El Gold Piso 9, Santiago, Santiago Metropolitan, Chile
# date_of_attack: 19.05.2024
# revenue: $25.1M
# industry: N/A
# data_volume: 460 GB
# data_description: Client confidential data - agreements\reports etc., Personal identification Information (passports, DL, etc), financial statements\reports, executives personal data, security officer private photos and files, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/rmdvmoiudrfwdhub.txt:
# company_name: DBMG
# address: 300 Commerce Ste 200, Irvine, California, 92602, United States
# date_of_attack: 28.12.2023
# revenue: $43.6M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/sbttziiflkfjouqk.txt:
# company_name: HUNDHAUSEN
# address: Bäckerstr. 4, 57076 Siegen. Germany
# date_of_attack: 10.07.2024
# revenue: $150M
# industry: N/A
# data_volume: 650 GB
# data_description: Corporate confidential data: projects, drawings, financial documents\payrolls, correspondence etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/sddgqdqcjgoefspn.txt:
# company_name: LARLYN
# address: 540 Wharncliffe Rd S Ste 200, London, Ontario, N6J 2N4, Canada
# date_of_attack: N/A
# revenue: $256.8M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/shijfijgmpbkvgul.txt:
# company_name: LOGO
# address: 4500 E Broad St, Columbus, Ohio, 43213, United States
# date_of_attack: N/A
# revenue: $850.6M
# industry: N/A
# data_volume: 35 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/sjfbtwefrrotvdkj.txt:
# company_name: ISOMETRIX
# address: 44 Milton Ave Ste 106, Alpharetta, Georgia, 30009, United States
# date_of_attack: 22.07.2024
# revenue: $45.8M
# industry: N/A
# data_volume: 126 GB
# data_description: Personal identifiable information, employees and executives personal files, financial data, customer information, contracts\NDA, corporate correspondence, software development data etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/snualkhfqjuuwaqy.txt:
# company_name: Logo
# address: 6 Logue Ct, Greenville, South Carolina, 29615, United States
# date_of_attack: N/A
# revenue: $66.1M
# industry: N/A
# data_volume: 39 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/sojbozoiawsokpmb.txt:
# company_name: NATCO
# address: 346 W Cerritos Ave, Glendale, California, 91204, United States
# date_of_attack: N/A
# revenue: $38.5M
# industry: N/A
# data_volume: 111 GB
# data_description: Employees personal and corporate data, customer information, corporate correspondence, database backups, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/syqnnuwnmxwlxwxk.txt:
# company_name: QUAKER
# address: 504 S Hwy 63, Freeburg, Missouri, 65035, United States
# date_of_attack: 12.01.2024
# revenue: $271.6M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/sztlticvnrggogaf.txt:
# company_name: SYSTEMS
# address: 4 Calle De O'donnell, Madrid, Madrid, 28009, Spain
# date_of_attack: 04.06.2024
# revenue: $17.3M
# industry: N/A
# data_volume: 11 GB
# data_description: Employees and executives personal and corporate data, financials, database exports, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/tbadwmxeceppsxyn.txt:
# company_name: 1234
# address: 55 Church St Ste 204, New Haven, Connecticut, 06510, United States
# date_of_attack: 18.12.2023
# revenue: $17.2M
# industry: N/A
# data_volume: 63 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/tcmgyvwurtygsjcc.txt:
# company_name: 12344
# address: 3500 Terminal Drive New Orleans, LA, 70115, USA
# date_of_attack: N/A
# revenue: $36.6M
# industry: N/A
# data_volume: 3 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/tczxmjmjlfkkqbtj.txt:
# company_name: REAWIRE
# address: 3400 E Coliseum Blvd Ste 200, Fort Wayne, Indiana, United States
# date_of_attack: 09.07.2024
# revenue: $100M
# industry: N/A
# data_volume: 100 GB
# data_description: Personal identifiable information, employees personal files, corporate agreements, projects, financial documents, personnel data, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/thikqcvecrhmqyee.txt:
# company_name: CONTENDERBOATS
# address: 1820 SE 38th Ave, Homestead, Florida, 33035, United States
# date_of_attack: 28.03.2024
# revenue: $51.8M
# industry: N/A
# data_volume: 65 GB
# data_description: Financial documents, Personal identification information. engineering documents and drawings, corporate correspondence, user personal folders, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/tqqxyqxjkuevimsb.txt:
# company_name: TLG
# address: 427 Bedford Rd, Pleasantville, New York, 10570, United States
# date_of_attack: N/A
# revenue: $66.1M
# industry: N/A
# data_volume: 2.4 TB
# data_description: Personal Identifiable Information, employees\executives personal data, corporate confidential documents, customer information, financial documents, corporate correspondence, database backups, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/tuiuwbkgbzvdaqps.txt:
# company_name: MILLIMAGES
# address: 88 Rue De La Folie Méricourt, Paris, Ile-de-France, 75011, France
# date_of_attack: 07.07.2024
# revenue: $12.6M
# industry: N/A
# data_volume: 147 GB
# data_description: Personal identifiable information, corporate confidential agreements, contracts, financial documents, personnel data, employees personal files, legal documents, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/tusbvjrewznemucs.txt:
# company_name: 12344444
# address: 1560 bloco 5 Av. Queiroz Filho Sala 301, Vila Hamburguesa, São Paulo, 05319-000, Brazil
# date_of_attack: 24.12.2023
# revenue: $66.1M
# industry: N/A
# data_volume: 730 GB
# ...
#
# Extracted data from file cactus scrapped txt/ulxvlfnaalpoygec.txt:
# company_name: 1234555
# address: 28 Nørregade, Hornsyld, Region Midtjylland, 8783, Denmark
# date_of_attack: 26.08.2023
# revenue: $21.8M
# industry: N/A
# data_volume: 70 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/umrrhztiwyvklhrk.txt:
# company_name: CANASIA
# address: 123 Great Gulf Dr, Concord, Ontario, L4K 5V1, Canada
# date_of_attack: 21.06.2024
# revenue: $29.6M
# industry: N/A
# data_volume: 327 GB
# data_description: Personal identifiable information, corporate confidential data, corporate correspondence, employees and executives personal files, financial documents, customer information, database backups, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/uwmjcdnqlpepqvpj.txt:
# company_name: GHIMLI
# address: 264 George Australia Square St L 42 Ste 4201, Sydney, New South Wales, 2000, Australia
# date_of_attack: N/A
# revenue: $189.1M
# industry: N/A
# data_volume: 88 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/uyzcgdjmjukgxldn.txt:
# company_name: 1664985237371
# address: 1 Rue Paul Mesplé, Toulouse, Midi Pyrénées, 31100, France
# date_of_attack: N/A
# revenue: $17.8M
# industry: N/A
# data_volume: 6 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/vatjohwxlmntizaw.txt:
# company_name: TRIDON
# address: 21 Derby St, Silverwater, New South Wales, 2128, Australia
# date_of_attack: 12.01.2024
# revenue: $34M
# industry: N/A
# data_volume: 175 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/vionjvasxvwxxrxh.txt:
# company_name: SUMMIT
# address: 35 rue Joseph Monier, Rueil Malmaison, 92500, France
# date_of_attack: 13.03.2024
# revenue: $66.1M
# industry: N/A
# data_volume: 1.5 TB
# data_description: Accounting\treasury\taxes 150GB+, HR - payrolls\personal documents\dossiers 30GB+, Customer data - projects\contracts\drawings 350GB+, Engineering\R&amp;D\QA 130GB+, corporate correspondence 100GB+, employees' personal folders... Lots of IDs, customer private data, contracts, confidential drawings and various corporate documents!
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/vjwvzwsmstjinwkp.txt:
# company_name: wwwww
# address: PO Box 521, Watertown, Wisconsin, 53094, United States
# date_of_attack: 20.12.2023
# revenue: $22.8M
# industry: N/A
# data_volume: 35 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/vogeuswtzqmpyfhw.txt:
# company_name: AERO
# address: 7472 Chapman Avenue, Garden Grove, California, 92841, United States
# date_of_attack: 15.04.2024
# revenue: $66.1M
# industry: N/A
# data_volume: 1.1 TB
# data_description: Engineering documents and drawings, confidential data and correspondence with various customers such as Boeing, SpaceX, Airbus etc., corporate correspondence, database backups\exports, employee personal documents and much more.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/voqpaogftrpyzlvz.txt:
# company_name: 111111
# address: 101 3rd St, Manchester, Kentucky, 40962, United States
# date_of_attack: 23.12.2023
# revenue: $35.5M
# industry: N/A
# data_volume: 800 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/wfpplxmasoxlfrvq.txt:
# company_name: APS
# address: 34501 Femrite Dr, Madison, Wisconsin, 53716, United States
# date_of_attack: 25.02.2024
# revenue: $66.1M
# industry: N/A
# data_volume: 54 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/wgetrkcyoixqormr.txt:
# company_name: PEERLESS
# address: 427 Ferry St At, Newark, New Jersey, 07105, United States
# date_of_attack: N/A
# revenue: $23.2M
# industry: N/A
# data_volume: 131 GB
# data_description: Personal Identifiable Information, database backups, employees\executives personal and corporate data, customer data, contracts\projects\drawings, financial documents, corporate correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/whvshrjkfrasgpkf.txt:
# company_name: 111111
# address: 547 Bickley Rd, Maddington, Western Australia, 6109, Australia
# date_of_attack: 29.09.2023
# revenue: $34.4M
# industry: N/A
# data_volume: 57 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/woxbbnehbgytxtaa.txt:
# company_name: REMKESBV
# address: 8 Kweekweg, Epe, Gelderland, 8161PG, Netherlands
# date_of_attack: 07.03.2024
# revenue: $31.4M
# industry: N/A
# data_volume: 190 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/wtfsbysrlushdwjw.txt:
# company_name: ALFA
# address: ul. Pograniczna 2/4, 02-285 Warsaw, Poland
# date_of_attack: 26.03.2024
# revenue: $66.5M
# industry: N/A
# data_volume: 638 GB
# data_description: Database exports, executive managers personal data, corporate data, financial documents, personal identification information, client information and much more.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/xaylczsmkcoibcrb.txt:
# company_name: GDI
# address: 695 90th Ave, Lasalle, Quebec, H8R 3A4, Canada
# date_of_attack: 12.01.2024
# revenue: $66.1M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/xbalanmrpuxfkhqq.txt:
# company_name: DOLLMAR
# address: 2 Via Bruno Buozzi 4, Caleppio Di Settala, Milano, 20090, Italy
# date_of_attack: 05.06.2024
# revenue: $28.3M
# industry: N/A
# data_volume: 127 GB
# data_description: Confidential corporate data, drawings, engineering files, Q&amp;A, personal identifying information, financial documents, corporate and personal correspondence, employee personal files, database backups, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/xgkylnvylkyionoc.txt:
# company_name: FPS
# address: 114 Industrial Dr, Gilberts, Illinois, 60136, United States
# date_of_attack: 21.06.2024
# revenue: $22.9M
# industry: N/A
# data_volume: 111 GB
# data_description: Employees and executives personal data, contracts, reports, customer data, personal identification information, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/xtiighwfvaagqlyy.txt:
# company_name: DILLARD
# address: 788 East St Ste 102, Memphis, Tennessee, 38104, United States
# date_of_attack: 28.12.2023
# revenue: $8.5M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/xvbczanisnpjimwq.txt:
# company_name: DRM
# address: 5324 N 134th Ave, Omaha, Nebraska, 68164, United States
# date_of_attack: 13.05.2024
# revenue: $266.6M
# industry: N/A
# data_volume: 175 GB
# data_description: Accounting\payroll documents, Personal Identifying information, HR documents, contracts, corporate correspondence, employees and executive managers personal folders, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/xwngfmmvrtefthvb.txt:
# company_name: OOGP
# address: 557 NE Westbrook Way, Grants Pass, Oregon, 9752, United States
# date_of_attack: 08.02.2024
# revenue: $11.4M
# industry: N/A
# data_volume: 63 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/xyvfmzpipjjodyot.txt:
# company_name: SIWILM
# address: 309 W Newport Pike, Wilmington, Delaware, 19804, United States
# date_of_attack: 03.09.2024
# revenue: $15.4M
# industry: N/A
# data_volume: 141 GB
# data_description: Corporate confidential data, Personal identifiable information, contracts, employees and executives personal files, financial documents, corporate correspondence, database exports\backups etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/yfrsokzczlrrowwg.txt:
# company_name: JMT
# address: 1002 E Chatham St 474, Cary, North Carolina, 27511, United States
# date_of_attack: 21.06.2024
# revenue: $17.9M
# industry: N/A
# data_volume: 331 GB
# data_description: Personal identification documents, employee personal files, confidential corporate data, projects, drawings, financial documents, supplier\customer information, &nbsp;corporate and personal correspondence, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/yfyegzrpulajewda.txt:
# company_name: 55555
# address: 506 Palestine Rd, Alto, Texas, 75925, United States
# date_of_attack: 24.12.2023
# revenue: $23.6M
# industry: N/A
# data_volume: 140 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ynpylxiipdaeuwfg.txt:
# company_name: BACHOCO
# address: 401 Avenida Tecnologico, San Martin de Camargo, Guanajuato, 38010, Mexico
# date_of_attack: 12.01.2024
# revenue: $66.1M
# industry: N/A
# data_volume: 130 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/yotykhnrrswfdqzc.txt:
# company_name: 555
# address: 25 Store St, London, Greater London, WC1E 7BL, United Kingdom
# date_of_attack: N/A
# revenue: $272.5M
# industry: N/A
# data_volume: 41 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/yprhdehlvtcutdpv.txt:
# company_name: 222222
# address: Orthum Bau GmbH - Pfarrhofstraße 10 - 84076 Rainertshausen
# date_of_attack: 20.12.2023
# revenue: $25.1M
# industry: N/A
# data_volume: 6 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/yqviwrrcmqtjihdg.txt:
# company_name: PLYMOUTH
# address: &nbsp;29W150 Warrenville Rd, Warrenville, IL 60555, United States
# date_of_attack: 20.03.2024
# revenue: $137M
# industry: N/A
# data_volume: 1.83 TB
# data_description: Accounting\treasury\taxes 250GB+, HR - payrolls\personal documents\dossiers 150GB+, Customer data - projects\contracts\drawings 90GB+, Engineering\R&amp;D\QA 120GB+, Legal documents 3GB+, corporate correspondence 20GB+, employees' personal folders... Hundreds of Personal Identifying information documents, executive managers personal and corporate documents, engineering database backups, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/yqzdecyebgxvnnxu.txt:
# company_name: 12344
# address: 2400 Geng Rd Ste 120, Palo Alto, California, 94303, United States
# date_of_attack: 22.12.2023
# revenue: $5M
# industry: N/A
# data_volume: 443 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ytjbsmcodsvfnbko.txt:
# company_name: 12444444
# address: 1325 Avenue of the Americas Fl 25, New York City, New York, 10019, United States
# date_of_attack: 30.07.2023
# revenue: $5.8M
# industry: N/A
# data_volume: 73 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/yxdlaioxpayilvig.txt:
# company_name: 1111111
# address: The Astro Building Midas River Way, Harlow, Essex, CM20 2GJ, United Kingdom
# date_of_attack: 19.12.2023
# revenue: $19.2M
# industry: N/A
# data_volume: 304 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/yxfonjnbaoqwabdp.txt:
# company_name: 123
# address: 2715 N Airport Commerce Ave, Springfield, Missouri, 65803, United States
# date_of_attack: 22.12.2023
# revenue: $17.4M
# industry: N/A
# data_volume: 84 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/yxvxsgxwesaijwrz.txt:
# company_name: ISC
# address: 70 Borgergade, Esbjerg, Region Syddanmark, 6700, Denmark
# date_of_attack: 19.12.2023
# revenue: $60.1M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/yywfzcgxmkgetajq.txt:
# company_name: HUNTER
# address: 14935 Jacintoport Blvd, Houston, Texas, 77015, United States
# date_of_attack: 28.12.2023
# revenue: $130.4M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/zcmoqbqvwvrcugig.txt:
# company_name: Fulcrum
# address: 5751 Kroger Dr Ste 279, Fort Worth, Texas, 76244, United States
# date_of_attack: 19.05.2024
# revenue: $2.1M
# industry: N/A
# data_volume: 57 GB
# data_description: Employees\executives personal data, corporate correspondence, agreements, private and corporate financial documents, personal identifying information, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/zkgemczmywlmqtuh.txt:
# company_name: logofin
# address: 16700 23 Mile Rd, Macomb, Michigan, 48044, United States
# date_of_attack: N/A
# revenue: $46.9M
# industry: N/A
# data_volume: 5 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/zkzndcwdwizzttgr.txt:
# company_name: MEDIMARKET
# address: 2 Blvd Anspach 2, Brussels, Brussels Capital, Belgium
# date_of_attack: 18.12.2023
# revenue: $164M
# industry: N/A
# data_volume: 2.4 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/znjqggmmmhuuydml.txt:
# company_name: HSS
# address: 90 Wilerstrasse, Sirnach, Thurgau, 8370, Switzerland
# date_of_attack: N/A
# revenue: $24.4M
# industry: N/A
# data_volume: 9 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/zqfgtqximzqlaspx.txt:
# company_name: VERHELST
# address: 30 Stationsstraat, Oudenburg, Flanders, 8460, Belgium
# date_of_attack: 17.12.2023
# revenue: $115.2M
# industry: N/A
# data_volume: 125 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/zqzetvoypiqdxilq.txt:
# company_name: SPB
# address: P. I. Castilla Vial 6, Cheste, Valencia, 46380, Spain
# date_of_attack: 18.02.2024
# revenue: $81.4M
# industry: N/A
# data_volume: 706 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/zryunuiixamtlmdj.txt:
# company_name: PARKSITE
# address: 1563 Hubbard Ave, Batavia, Illinois, 60510, United States
# date_of_attack: 18.02.2024
# revenue: $452.7M
# industry: N/A
# data_volume: 170 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/zsogqltdhscjvvrs.txt:
# company_name: FAMILYGYARDIAN
# address: East Bay &amp; Church Streets, Nassau, Bahamas
# date_of_attack: N/A
# revenue: $51.7M
# industry: N/A
# data_volume: 1.5 TB
# data_description: Hundreds of confidential client documents and personal identifying information (passports, utility bills, contracts), corporate correspondence, employee phones backups, executives personal data, database backups, etc.
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ztprilgnosbxbzxv.txt:
# company_name: LOGONOVOBIT
# address: 54 Knonauerstrasse, Cham, Zug, 6330, Switzerland
# date_of_attack: N/A
# revenue: $39.4M
# industry: N/A
# data_volume: 23 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file cactus scrapped txt/ztuapaxflcesiowg.txt:
# company_name: 11111
# address: 100 E Washington St Ste 220, Belleville, Illinois, 62220, United States
# date_of_attack: 22.12.2023
# revenue: $58.3M
# industry: N/A
# data_volume: 157 GB
# data_description: N/A
#
# --------------------------------------------------
