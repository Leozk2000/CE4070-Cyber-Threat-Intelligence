# %%
import csv

# %%
file_name = './hunters_international_filtered_categorized.csv'

with open(file_name, 'r') as file:
    reader = csv.reader(file)
    rows = [row for row in reader]
    company_names = [row[0] for row in rows[1:]]

print(company_names)
# Out:
# ['Robertson Cheatham Farmers', 'Hallesche Kraftverkehrs & Speditions GmbH', 'Crowe', 'Magicolor', 'Arcmed Group', 'Mid-South Health Systems', 'Bartlett & Weigle Co. LPA.', 'Optima Manufacturing', 'NetVigour', 'Trade-Mark Industrial', 'RÃ©seau RibÃ©', 'SOPEM', 'Paulmann Licht', 'Alupar Investimento SA', 'Inszone Insurance Services', 'Carespring Health Care', 'Finlay Screening & Crushing Systems', 'ATL Leasing', 'Chicago Zoological Society', 'Jess-link Products', 'Wapiti Energy', 'Tamdown', 'Integrated Control', 'Durham Manufacturing', 'Ð¡oquitlam Concrete', "Jordano's Inc.", 'DataBank', 'Circle K Atlanta', 'Sun Holdings', 'Caxton and CTP Publishers and Printers', 'RAVEN Mechanical', 'Bojanglesâ€™ International', 'Hanon Systems', 'Benchmark Management Group', "Lancaster County Sheriff's Office", 'City of St. Cloud, Florida', 'Jangho Group', 'SuperDrob S.A.', 'DiVal Safety Equipment, Inc.', 'Kaplan', 'Northeast Rehabilitation Hospital Network', 'Ducont', 'R.C. Moore Trucking', 'Hibser Y
# ...

# %%
# I took this from ChatGPT (some i corrected)
industry_types = [
    'Agriculture',  # Robertson Cheatham Farmers
    'Logistics & Transportation',  # Hallesche Kraftverkehrs & Speditions GmbH
    'Professional Services',  # Crowe
    'Technology',  # Magicolor
    'Medical Devices',  # Arcmed Group
    'Healthcare',  # Mid-South Health Systems
    'Legal Services',  # Bartlett & Weigle Co. LPA.
    'Manufacturing',  # Optima Manufacturing
    'Cloud Computing',  # NetVigour
    'Construction & Industrial Services',  # Trade-Mark Industrial
    'Technology',  # Réseau Ribé
    'Manufacturing',  # SOPEM
    'Lighting',  # Paulmann Licht
    'Energy & Utilities',  # Alupar Investimento SA
    'Insurance',  # Inszone Insurance Services
    'Healthcare',  # Carespring Health Care
    'Mining & Construction',  # Finlay Screening & Crushing Systems
    'Leasing Services',  # ATL Leasing
    'Non-Profit / Zoological Services',  # Chicago Zoological Society
    'Electronics',  # Jess-link Products
    'Energy',  # Wapiti Energy
    'Construction',  # Tamdown
    'Automation & Control Systems',  # Integrated Control
    'Manufacturing',  # Durham Manufacturing
    'Construction',  # Coquitlam Concrete
    'Food & Beverage',  # Jordano's Inc.
    'Data Centers & IT',  # DataBank
    'Retail & Convenience Stores',  # Circle K Atlanta
    'Food & Beverage',  # Sun Holdings
    'Printing & Publishing',  # Caxton and CTP Publishers and Printers
    'Mechanical Services',  # RAVEN Mechanical
    'Food & Beverage',  # Bojangles’ International
    'Automotive',  # Hanon Systems
    'Real Estate & Management',  # Benchmark Management Group
    'Government',  # Lancaster County Sheriff's Office
    'Government',  # City of St. Cloud, Florida
    'Construction',  # Jangho Group
    'Food & Beverage',  # SuperDrob S.A.
    'Safety Equipment',  # DiVal Safety Equipment, Inc.
    'Education',  # Kaplan
    'Healthcare',  # Northeast Rehabilitation Hospital Network
    'Technology',  # Ducont
    'Logistics & Transportation',  # R.C. Moore Trucking
    'Architecture',  # Hibser Yamauchi Architects
    'Sales & Distribution',  # Rocky Mountain Sales
    'Non-Profit',  # Project M.O.R.E.
    'Manufacturing',  # Harper Industries
    'Healthcare',  # HOYA Corporation
    'Manufacturing',  # Pella
    'Medical Devices',  # Acteon Group
    'Wine & Spirits Distribution',  # Frederick Wildman and Sons
    'Energy & Utilities',  # Carigali Hess Operating Company
    'Accounting Services',  # Gibbs Hurley Chartered Accountants
    'Semiconductors',  # Navitas Semiconductor
    'CRM Software',  # Legrand CRM
    'Manufacturing & Machinery',  # CLARK Material Handling Company
    'Energy & Oil',  # Anderson Oil & Gas
    'Advertising',  # Sting AD
    'Logistics & Transportation',  # Schuster Trucking Company
    'Agriculture',  # Priefert
    'Financial Services',  # Communication Federal Credit Union
    'Food & Beverage Distribution',  # Kreyenhop & Kluge
    'Technology & Displays',  # NanoLumens
    'Real Estate',  # T A Khoury
    'Healthcare',  # Sindicato de Enfermería (SATSE)
    'Energy',  # AGL
    'Fashion',  # Benetton Group
    'Industrial Services',  # Jack Doheny Company
    'Education & Non-Profit',  # Aftrp
    'Technology Services',  # PSI
    'Retail',  # Intersport
    'Electronics',  # Chicony Electronics
    'Pharmaceuticals',  # Khandelwal Laboratories Pvt
    'Public Relations',  # Ferraro Group
    'Travel & Tourism',  # Miki Travel
    'Hospitality',  # Dalmahoy Hotel & Country Club
    'Architecture & Planning',  # Seamon Whiteside
    'Construction',  # Concrete
    'Healthcare',  # Omni Family Health
    'Flooring & Interiors',  # Interface
    'Logistics & Trade',  # Manuchar
    'Education',  # Gallup McKinley County Schools
    'Holding Company',  # Akkanat Holding
    'Manufacturing',  # MS Ultrasonic Technology Group
    'Aerospace',  # Avianor Aircraft
    'Automotive Parts',  # WheelerShip
    'Government',  # Kenya Urban Roads Authority
    'Healthcare',  # Betances Health Center
    'Government',  # St. Johns River Water Management District
    'Construction',  # Groupe Goyette
    'Manufacturing',  # Aero Tec Laboratories
    'Government',  # Concello de Teo
    'Industrial Services',  # Griffin Dewatering
    'Legal Services',  # Gunning & LaFazia, Inc.
    'Technology',  # HSI
    'Electrical Services',  # Impact Energy Services
    'Medical Technology',  # Sysmex
    'Technology',  # Fractalia Group
    'Technology & Outsourcing',  # Exela Technologies
    'Government',  # Treasury of Cote d'Ivoire
    'Healthcare',  # Therapeutic Health Services
    'Insurance',  # BeneCare Dental Insurance
    'Food & Beverage Manufacturing',  # Richelieu Foods
    'Government',  # Physical & Occupational Therapy Examiners of Texas
    'Communications & IT',  # ComNet Communications
    'Real Estate',  # MRI
    'Automotive',  # Toyota Brazil
    'Automotive',  # Tiete Automobile
    'Healthcare & Supplies',  # SSS Australia
    'Construction',  # Kleven Construction
    'Government',  # Greater Napanee
    'Industrial Equipment',  # Thorite Group
    'Energy',  # Indika Energy
    'Technology',  # Cosmocolor
    'Food & Beverage',  # Braum's Inc
    'Construction & Design',  # Thermosash Commercial Ltd
    'Retail & Distribution',  # Notions Marketing
    'Technology',  # Voice Technologies
    'Industrial Equipment',  # Crownlea Group
    'Telecommunications',  # NetOne
    'Logistics & Transportation',  # ACE Air Cargo
    'Construction',  # IJM Corporation
    'Industrial Automation',  # Ausa
    'Technology & Automation',  # Innovative Automation
    'Energy',  # Axip Energy Services
    'Translation & Localization',  # Crimson Interactive
    'Technology',  # Nastech
    'Government',  # Village of Skokie
    'Technology',  # Lantronix Inc.
    'Safety Systems',  # BS&B Safety Systems L.L.C
    'Broadcasting & Communications',  # CP Communications
    'Chemicals & Plastics',  # Formosa Plastics USA
    'Manufacturing',  # Panzeri Cattaneo
    'Government',  # ENEA Italy
    'Agriculture & Co-op',  # Arrabawn Co-op
    'Education & Ethics',  # LRN
    'Retail',  # Citi Trends
    'Automotive Recycling',  # Charles Trent
    'Aerospace',  # The Gill Corporation
    'Technology',  # Multisuns Communication
    'Technology & Services',  # ACS
    'Government',  # Santa Rosa
    'Healthcare',  # Bradford Health
    'Cabling & Electronics',  # Kablutronik SRL
    'Industrial Services',  # Central Power Systems and Services
    'Hospitality & Resorts',  # Beaver Run Resort
    'Real Estate & Historic Preservation',  # Casco Antiguo
    'Government'  # Treasury of Cote d'Ivoire
]

# %%
# replace column index 4 with the industry type
for i, (industry_type, row) in enumerate(zip(industry_types, rows[1:])):
    row[4] = industry_type

# %%
# Save as a new file
new_file_name = './hunters_international_filtered_categorized_industry.csv'

with open(new_file_name, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(rows)

print(f"Saved as {new_file_name}")
# Out:
# Saved as ./hunters_international_filtered_categorized_industry.csv
