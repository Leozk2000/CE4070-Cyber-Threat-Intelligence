# %%
import csv
import zipfile
import re
from bs4 import BeautifulSoup

company_name_pattern = r'<h2>(.*?)</h2>'
country_pattern = r'<p class="attrs">Country: <span class="old">(.*?)</span></p>'
date_pattern = r'data-deadline="(.*?)"'
revenue_pattern = r'<p class="attrs">Revenue: <span class="old">(.*?)</span></p>'
industry_pattern = r'<p class="attrs">Industry: <span class="old">(.*?)</span></p>'
data_volume_pattern = r'(\d+(?:\.\d+)?)\s?(TB|Tb|GB|Gb)'
data_description_pattern = r'company:\s*(.*)</p>'  

extracted_data = []

def extract_data(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')

    company_name = re.search(company_name_pattern, html_content)
    country = re.search(country_pattern, html_content)
    attack_date = re.search(date_pattern, html_content)
    revenue = re.search(revenue_pattern, html_content)
    industry = re.search(industry_pattern, html_content)
    data_volume = re.findall(data_volume_pattern, html_content)
    data_description = re.search(data_description_pattern, html_content)

    if data_volume:
        data_volume = f"{data_volume[0][0]} {data_volume[0][1]}"  # Combine the number and unit
    else:
        data_volume = 'N/A'

    data = {
        'company_name': company_name.group(1) if company_name else 'N/A',
        'country': country.group(1) if country else 'N/A',
        'date_of_attack': attack_date.group(1) if attack_date else 'N/A',
        'revenue': revenue.group(1) if revenue else 'N/A',
        'industry': industry.group(1) if industry else 'N/A',
        'data_volume': data_volume,
        'data_description': data_description.group(1).strip() if data_description else 'N/A',
        
    }

    return data

zip_file_path = 'C:\\Users\\Sruthi\\OneDrive\\Sruthi\\Studies\\Uni\\Uni Courses-Sruthi-Zenbook\\Year 3 Sem 1\\Cyber Threat Intelligence\\Project\\danon\\dAn0n scrapped txt.zip'

with zipfile.ZipFile(zip_file_path, 'r') as z:
    for file_name in z.namelist():
        with z.open(file_name) as file:
            content = file.read().decode('utf-8')
            extracted_info = extract_data(content)
            extracted_data.append(extract_data(content))
            print(f"Extracted data from file {file_name}:")
            for key, value in extracted_info.items():
                print(f"{key}: {value}")
            print("\n" + "-"*50 + "\n")

csv_columns = ['company_name', 'country', 'date_of_attack', 'revenue', 'industry', 'data_volume', 'data_description']

csv_file = 'extracted_data.csv'
try:
    with open('danon_extracted_data.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for data in extracted_data:
            writer.writerow(data)
except IOError:
    print("I/O error")
# Out:
# Extracted data from file dAn0n scrapped txt/:
# company_name: N/A
# country: N/A
# date_of_attack: N/A
# revenue: N/A
# industry: N/A
# data_volume: N/A
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/cyjpjnylhbcozbxn.txt:
# company_name: RSH legal
# country: USA
# date_of_attack: Apr 29, 2024 14:04:54
# revenue: $5.6M
# industry: Law Firms &amp; Legal Services
# data_volume: 6 TB
# data_description: Financial, legal, medical information of clients and employees, personal data employees, partners and clients.
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/dlvzmycbvlcrbwvp.txt:
# company_name: Erler &amp; Kalinowski
# country: USA
# date_of_attack: May 17, 2024 09:05:43
# revenue: $14.5 M
# industry: Architecture, Engineering &amp; Design
# data_volume: 1 TB
# data_description: Financial, legal, information on employees and partners. Information on clients was also received: Personal data of clients, all signed contracts and transactions, legal information of clients.
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/dxjesbeknjrdpyrb.txt:
# company_name: The Blake Law Firm
# country: USA
# date_of_attack: Apr 08, 2024 14:04:54
# revenue: &lt;$5M
# industry: Law Firms &amp; Legal Services
# data_volume: 740 GB
# data_description: Financial, legal, information on employees and partners. Information on clients was also received: Personal data of clients, all signed contracts and transactions.
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/gqjmksmyzkbbjcpm.txt:
# company_name: Dunn Solutions
# country: US
# date_of_attack: Aug 19, 2024 09:08:26
# revenue: 36.1M
# industry: Business Services
# data_volume: 1.12 Tb
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/gvknelrnplinlxto.txt:
# company_name: Semilab
# country: US
# date_of_attack: Apr 21, 2024 13:04:01
# revenue: $16.8M
# industry: Electronics
# data_volume: 1.47 TB
# data_description: Financial, legal, information on employees, partners and clientsб drawingы and scheme of constructions.
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/hmxlkjoizdalkwey.txt:
# company_name: College Park Industries
# country: USA
# date_of_attack: Jun 07, 2024 20:06:10
# revenue: $22.4M
# industry: Medical Devices &amp; Equipment
# data_volume: 4.97 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/mntcllpvpuittomm.txt:
# company_name: O&#x27;Connell Mahon Architects
# country: Ireland
# date_of_attack: May 04, 2024 10:05:53
# revenue: $5.4M
# industry: Architecture, Engineering &amp; Design
# data_volume: 1 TB
# data_description: Financial and legal documents, architectural projects, personal data of employees, partners and clients.
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/mqvxvjqebzahpihj.txt:
# company_name: Allen Blasting and Coating
# country: US
# date_of_attack: Apr 18, 2024 14:04:54
# revenue: $20M
# industry: Specialty Trade Contractors
# data_volume: 1 TB
# data_description: Financial, legal, information on employees, partners and clients.
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/musdguyzunqgtqqm.txt:
# company_name: FIFCO USA
# country: USA
# date_of_attack: Jun 27, 2024 12:06:00
# revenue: $310.6M
# industry: Wineries &amp; Breweries
# data_volume: 7.09 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/ogeavspbckqeogdy.txt:
# company_name: Information Integration Experts
# country: USA
# date_of_attack: May 17, 2024 10:05:53
# revenue: $5M
# industry: Software
# data_volume: 1043 GB
# data_description: SRC, DBs, office docs, scans, credentials for local and remote services, information on employees and partners, personal data of clients.
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/omgrmfaehprbpaxh.txt:
# company_name: United Equitable Group
# country: USA
# date_of_attack: Apr 12, 2024 14:04:54
# revenue: $9.2M
# industry: Insurance
# data_volume: 300 GB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/oxqdxdzrgkafeawq.txt:
# company_name: M&amp;M Transport Services
# country: US
# date_of_attack: Aug 24, 2024 00:08:48
# revenue: 28.2M
# industry: Logistics
# data_volume: 868 Gb
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/phthxmdlezwzryoy.txt:
# company_name: S&amp;F Concrete Contractors
# country: US
# date_of_attack: Jun 02, 2024 16:06:35
# revenue: $30.9M
# industry: Commercial &amp; Residential Construction
# data_volume: 1 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/qmeoascjtgcxlhgg.txt:
# company_name: Stahly Engineering &amp; Associates
# country: US
# date_of_attack: Sep 09, 2024 07:09:29
# revenue: 14.4M
# industry: Architecture, Engineering &amp; Design
# data_volume: 1.2 Tb
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/rkdhbrkuuphnajpb.txt:
# company_name: N/A
# country: N/A
# date_of_attack: Sep 09, 2024 07:09:29
# revenue: N/A
# industry: N/A
# data_volume: 1.78 TB
# data_description: Financial, legal, information on employees and partners. Information on clients was also received:...
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/usqjbgqbuzxhxhak.txt:
# company_name: Glenwood Management
# country: USA
# date_of_attack: May 18, 2024 15:05:40
# revenue: $49.1M
# industry: Real estate
# data_volume: 1.78 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/vpkncpfwsyydhtaj.txt:
# company_name: PromarkBRANDS
# country: USA
# date_of_attack: Jul 07, 2024 09:07:22
# revenue: $11.6M
# industry: Consumer Services
# data_volume: 1.45 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/xdkwmwtqkyijenwe.txt:
# company_name: Northeast Orthopedics and Sports Medicine
# country: USA
# date_of_attack: May 18, 2024 15:05:40
# revenue: $15M
# industry: Healthcare
# data_volume: 1.56 TB
# data_description: N/A
#
# --------------------------------------------------
#
# Extracted data from file dAn0n scrapped txt/zzuubzhimkfthboa.txt:
# company_name: Pediatric Urology Associates
# country: USA
# date_of_attack: Apr 07, 2024 09:04:10
# revenue: $45M
# industry: Hospitals &amp; Physicians Clinics
# data_volume: 740 GB
# data_description: Financial, legal, information on employees and partners. Information on clients was also received: Personal data of clients and employees.
#
# --------------------------------------------------
